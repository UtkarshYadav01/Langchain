# %% [markdown]
# ### Vector stores and retrievers
# This video tutorial will familiarize you with LangChain's vector store and retriever abstractions. These abstractions are designed to support retrieval of data-- from (vector) databases and other sources-- for integration with LLM workflows. They are important for applications that fetch data to be reasoned over as part of model inference, as in the case of retrieval-augmented generation.
#
# We will cover
# - Documents
# - Vector stores
# - Retrievers

# %%
# !pip install langchain
# !pip install langchain-chroma
# !pip install langchain_groq
# Out:
# Requirement already satisfied: langchain in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (0.3.80)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (0.4.32)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (2.12.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith>=0.1.17->langchain) (0.24.0)
# Requirement already satisfied: anyio in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.10.0)
# Requirement already satisfied: certifi in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3,>=2->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: langchain-chroma in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (0.2.6)
# Requirement already satisfied: langchain-core>=0.3.76 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-chroma) (0.3.80)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-chroma) (2.2.5)
# Requirement already satisfied: chromadb>=1.0.20 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-chroma) (1.3.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: pydantic>=1.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (2.12.3)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (5.4.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.20.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (3.11.4)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from chromadb>=1.0.20->langchain-chroma) (4.25.0)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.32.5)
# Requirement already satisfied: six>=1.5 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests<3.0,>=2.7->posthog<6.0.0,>=2.4.0->chromadb>=1.0.20->langchain-chroma) (2025.11.12)
# Requirement already satisfied: packaging>=19.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (25.0)
# Requirement already satisfied: pyproject_hooks in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from build>=1.0.3->chromadb>=1.0.20->langchain-chroma) (2.2.1)
# Requirement already satisfied: anyio in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.20->langchain-chroma) (0.28.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (0.6.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core>=0.3.76->langchain-chroma) (0.4.32)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core>=0.3.76->langchain-chroma) (1.33)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.3.76->langchain-chroma) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.76->langchain-chroma) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.3.76->langchain-chroma) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.20->langchain-chroma) (0.4.2)
# Requirement already satisfied: coloredlogs in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (25.9.23)
# Requirement already satisfied: protobuf in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (5.29.3)
# Requirement already satisfied: sympy in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.20->langchain-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.38.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-proto==1.38.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.20->langchain-chroma) (1.38.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=1.0.20->langchain-chroma) (0.59b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.20->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (0.36.0)
# Requirement already satisfied: filelock in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.20->langchain-chroma) (2025.10.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.20->langchain-chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.2.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.20->langchain-chroma) (15.0.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb>=1.0.20->langchain-chroma) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.20->langchain-chroma) (1.3.0)
# Requirement already satisfied: langchain_groq in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (0.3.8)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.75 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain_groq) (0.3.80)
# Requirement already satisfied: groq<1,>=0.30.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain_groq) (0.34.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (2.12.3)
# Requirement already satisfied: sniffio in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from groq<1,>=0.30.0->langchain_groq) (4.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain_groq) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.30.0->langchain_groq) (3.11)
# Requirement already satisfied: certifi in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.30.0->langchain_groq) (0.16.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (0.4.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (6.0.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.75->langchain_groq) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.30.0->langchain_groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.75->langchain_groq) (2.3.0)

# %% [markdown]
# ### Documents
# LangChain implements a Document abstraction, which is intended to represent a unit of text and associated metadata. It has two attributes:
#
# - page_content: a string representing the content;
# - metadata: a dict containing arbitrary metadata.
# The metadata attribute can capture information about the source of the document, its relationship to other documents, and other information. Note that an individual Document object often represents a chunk of a larger document.
#
# Let's generate some sample documents:

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Goldfish are popular pets for beginners, requiring relatively simple care.",
        metadata={"source": "fish-pets-doc"},
    ),
    Document(
        page_content="Parrots are intelligent birds capable of mimicking human speech.",
        metadata={"source": "bird-pets-doc"},
    ),
    Document(
        page_content="Rabbits are social animals that need plenty of space to hop around.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
documents
# Out:
# [Document(metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(metadata={'source': 'fish-pets-doc'}, page_content='Goldfish are popular pets for beginners, requiring relatively simple care.'),
#  Document(metadata={'source': 'bird-pets-doc'}, page_content='Parrots are intelligent birds capable of mimicking human speech.'),
#  Document(metadata={'source': 'mammal-pets-doc'}, page_content='Rabbits are social animals that need plenty of space to hop around.')]

# %%
import os
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq
groq_api_key=os.getenv("GROQ_API_KEY")

os.environ["HF_TOKEN"]=os.getenv("HF_TOKEN")

llm=ChatGroq(groq_api_key=groq_api_key,model="groq/compound")
llm
# Out:
# ChatGroq(client=<groq.resources.chat.completions.Completions object at 0x0000020950C36A40>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020950C36140>, model_name='groq/compound', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (0.3.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain_huggingface) (0.3.80)
# Requirement already satisfied: tokenizers>=0.19.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain_huggingface) (0.19.1)
# Requirement already satisfied: huggingface-hub>=0.33.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain_huggingface) (0.36.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.4.32)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (2.12.3)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.24.0)
# Requirement already satisfied: anyio in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (4.10.0)
# Requirement already satisfied: certifi in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.4 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (0.4.2)
# Requirement already satisfied: filelock in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (2025.10.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from huggingface-hub>=0.33.4->langchain_huggingface) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (2.3.0)
# Requirement already satisfied: colorama in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.33.4->langchain_huggingface) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\utkar\documents\code\langchain\venv\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain_huggingface) (1.3.0)

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")

# %%
## VectorStores
from langchain_chroma import Chroma

vectorstore=Chroma.from_documents(documents,embedding=embeddings)
vectorstore

# %%
vectorstore.similarity_search("cat")
# Out:
# [Document(id='6786b13d-6ed0-418b-a76e-610b8e8e234c', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='6afd1c24-6e94-4d79-83e2-fa1f11840989', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='5ea6f0f1-de8c-467e-bfd8-27c8e47cc386', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='9087d86c-5971-483c-93d0-a0acaece975e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
## Async query
await vectorstore.asimilarity_search("cat")
# Out:
# [Document(id='6786b13d-6ed0-418b-a76e-610b8e8e234c', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='6afd1c24-6e94-4d79-83e2-fa1f11840989', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#  Document(id='5ea6f0f1-de8c-467e-bfd8-27c8e47cc386', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#  Document(id='9087d86c-5971-483c-93d0-a0acaece975e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]

# %%
vectorstore.similarity_search_with_score("cat")
# Out:
# [(Document(id='6786b13d-6ed0-418b-a76e-610b8e8e234c', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#   0.9351057410240173),
#  (Document(id='6afd1c24-6e94-4d79-83e2-fa1f11840989', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.'),
#   0.9351057410240173),
#  (Document(id='5ea6f0f1-de8c-467e-bfd8-27c8e47cc386', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#   1.574089765548706),
#  (Document(id='9087d86c-5971-483c-93d0-a0acaece975e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.'),
#   1.574089765548706)]

# %% [markdown]
# ### Retrievers
# LangChain VectorStore objects do not subclass Runnable, and so cannot immediately be integrated into LangChain Expression Language chains.
#
# LangChain Retrievers are Runnables, so they implement a standard set of methods (e.g., synchronous and asynchronous invoke and batch operations) and are designed to be incorporated in LCEL chains.
#
# We can create a simple version of this ourselves, without subclassing Retriever. If we choose what method we wish to use to retrieve documents, we can create a runnable easily. Below we will build one around the similarity_search method:

# %%
from typing import List

from langchain_core.documents import Document
from langchain_core.runnables import RunnableLambda

retriever=RunnableLambda(vectorstore.similarity_search).bind(k=1)
retriever.batch(["cat","dog"])
# Out:
# [[Document(id='6786b13d-6ed0-418b-a76e-610b8e8e234c', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(id='9087d86c-5971-483c-93d0-a0acaece975e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %% [markdown]
# Vectorstores implement an as_retriever method that will generate a Retriever, specifically a VectorStoreRetriever. These retrievers include specific search_type and search_kwargs attributes that identify what methods of the underlying vector store to call, and how to parameterize them. For instance, we can replicate the above with the following:

# %%
retriever=vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={"k":1}
)
retriever.batch(["cat","dog"])
# Out:
# [[Document(id='6786b13d-6ed0-418b-a76e-610b8e8e234c', metadata={'source': 'mammal-pets-doc'}, page_content='Cats are independent pets that often enjoy their own space.')],
#  [Document(id='9087d86c-5971-483c-93d0-a0acaece975e', metadata={'source': 'mammal-pets-doc'}, page_content='Dogs are great companions, known for their loyalty and friendliness.')]]

# %%
## RAG
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnablePassthrough

message = """
Answer this question using the provided context only.

{question}

Context:
{context}
"""
prompt = ChatPromptTemplate.from_messages([("human", message)])

rag_chain={"context":retriever,"question":RunnablePassthrough()}|prompt|llm

response=rag_chain.invoke("tell me about dogs")
print(response.content)
# Out:
# Dogs are great companions, celebrated for their loyalty and friendliness.

# %% [markdown]
# retrievers is also in **4.2-Chroma.ipynb**
